# %%
### Walmart data EDA ###

# %%
#Read pickle 
import pickle

with open('walmart_df.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
df=pd.DataFrame(data)
df
# Out:
#                date  store_nbr  item_nbr  units  station_nbr tmax tmin tavg  \
# 0        2012-01-01          1         1      0            1   52   31   42
# 1        2012-01-01          1         2      0            1   52   31   42
# 2        2012-01-01          1         3      0            1   52   31   42
# 3        2012-01-01          1         4      0            1   52   31   42
# 4        2012-01-01          1         5      0            1   52   31   42
# 5        2012-01-01          1         6      0            1   52   31   42
# 6        2012-01-01          1         7      0            1   52   31   42
# 7        2012-01-01          1         8      0            1   52   31   42
# 8        2012-01-01          1         9     29            1   52   31   42
# 9        2012-01-01          1        10      0            1   52   31   42
# 10       2012-01-01          1        11      0            1   52   31   42
# ...

# %%
df.describe()
# Out:
#           store_nbr      item_nbr         units   station_nbr
# count  4.617600e+06  4.617600e+06  4.617600e+06  4.617600e+06
# mean   2.309108e+01  5.600000e+01  9.868756e-01  1.132329e+01
# std    1.295281e+01  3.204164e+01  9.875798e+00  4.946884e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00
# 25%    1.200000e+01  2.800000e+01  0.000000e+00  7.000000e+00
# 50%    2.300000e+01  5.600000e+01  0.000000e+00  1.200000e+01
# 75%    3.400000e+01  8.400000e+01  0.000000e+00  1.500000e+01
# max    4.500000e+01  1.110000e+02  5.568000e+03  2.000000e+01

# %%
df.dtypes
# Out:
# date           object
# store_nbr       int64
# item_nbr        int64
# units           int64
# station_nbr     int64
# tmax           object
# tmin           object
# tavg           object
# depart         object
# dewpoint       object
# wetbulb        object
# heat           object
# cool           object
# sunrise        object
# sunset         object
# codesum        object
# snowfall       object
# preciptotal    object
# stnpressure    object
# sealevel       object
# resultspeed    object
# resultdir      object
# avgspeed       object
# dtype: object

# %%
# date to time series data : string -> date 
df['date']= pd.to_datetime(df['date'])
df['date']
# Out:
# 0         2012-01-01
# 1         2012-01-01
# 2         2012-01-01
# 3         2012-01-01
# 4         2012-01-01
# 5         2012-01-01
# 6         2012-01-01
# 7         2012-01-01
# 8         2012-01-01
# 9         2012-01-01
# 10        2012-01-01
# 11        2012-01-01
# 12        2012-01-01
# 13        2012-01-01
# 14        2012-01-01
# 15        2012-01-01
# 16        2012-01-01
# 17        2012-01-01
# 18        2012-01-01
# 19        2012-01-01
# 20        2012-01-01
# 21        2012-01-01
# 22        2012-01-01
# 23        2012-01-01
# 24        2012-01-01
# 25        2012-01-01
# 26        2012-01-01
# 27        2012-01-01
# 28        2012-01-01
# 29        2012-01-01
#              ...
# 4617570   2014-10-31
# 4617571   2014-10-31
# 4617572   2014-10-31
# 4617573   2014-10-31
# 4617574   2014-10-31
# 4617575   2014-10-31
# 4617576   2014-10-31
# 4617577   2014-10-31
# 4617578   2014-10-31
# 4617579   2014-10-31
# 4617580   2014-10-31
# 4617581   2014-10-31
# ...

# %%
# time series EDA 
# sales/item over time 
#     a. day, month, year 
#     b. weekday, weekend 
#     v. event date (thanksgiving, christmas)

# %%
df['item_nbr'].dtypes
# Out:
# dtype('int64')

# %%
df['item_nbr'].tail()
# Out:
# 4617595    107
# 4617596    108
# 4617597    109
# 4617598    110
# 4617599    111
# Name: item_nbr, dtype: int64

# %%
plt.scatter(df['item_nbr'], df['units'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# timeseries graph : sales volume over time by items 
# https://machinelearningmastery.com/time-series-data-visualization-with-python/
from pandas import series 

series = Series.from_csv('daily-minimum-temperatures.csv', header=0)
series.plot(style='k.')
pyplot.show()

df['date'], df['units'], df['item_nbr']
plt.show()
# Out:
# <div id='21114413-83e6-431e-bda4-887d8b5d189e'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6829157ff298> in <module>()
# ----> 1 plt.scatter(df['date'], df['units'])
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
# ...
